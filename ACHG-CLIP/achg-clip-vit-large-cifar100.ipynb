# %% [markdown]
# # ACHG-CLIP: Experiment B2 (ViT-L/14 Backbone Study)
# This notebook trains and evaluates the ACHG-CLIP model on CIFAR-100 FSCIL using the **ViT-L/14** backbone with **Seed 42**.

# %%
import torch
print('='*50)
print(f'CUDA Available : {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'Device Name    : {torch.cuda.get_device_name(0)}')
    print(f'Device VRAM    : {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB')
print('='*50)
# Out:
# ==================================================
# CUDA Available : True
# Device Name    : Tesla P100-PCIE-16GB
# Device VRAM    : 17.06 GB
# ==================================================
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:435: UserWarning:
#     Found GPU0 Tesla P100-PCIE-16GB which is of cuda capability 6.0.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (7.0) - (12.0)
#
#   queued_call()
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:435: UserWarning:
#     Please install PyTorch with a following CUDA
#     configurations:  12.6 following instructions at
#     https://pytorch.org/get-started/locally/
#
#   queued_call()
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:435: UserWarning:
# Tesla P100-PCIE-16GB with CUDA capability sm_60 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_70 sm_75 sm_80 sm_86 sm_90 sm_100 sm_120.
# If you want to use the Tesla P100-PCIE-16GB GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   queued_call()

# %%
# !pip install -q torch==2.2.2 torchvision==0.17.2 --index-url https://download.pytorch.org/whl/cu118
# !pip install -q transformers ftfy regex pyyaml "numpy<2"

import os
if not os.path.exists('/kaggle/working/FSCIL'):
    # !git clone https://github.com/Siddarth021/FSCIL.git /kaggle/working/FSCIL

os.chdir('/kaggle/working/FSCIL/ACHG-CLIP')
print(f'Working directory: {os.getcwd()}')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.1/819.1 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 113.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 75.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 47.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 104.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.5/728.5 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 33.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 MB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.10.0+cu128 requires torch==2.10.0, but you have torch 2.2.2+cu118 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 905.3 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 59.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# kaggle-environments 1.29.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.3.1 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# Cloning into '/kaggle/working/FSCIL'...
# remote: Enumerating objects: 130, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 130 (delta 6), reused 130 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (130/130), 285.37 KiB | 2.08 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# Working directory: /kaggle/working/FSCIL/ACHG-CLIP

# %%
# Write latest run_cifar100.py
code_cifar = "import os\nimport sys\nimport yaml\nimport time\nimport json\nimport torch\nimport torch.nn as nn\nimport argparse\nimport shutil\nfrom datetime import datetime\n\nfrom data.registry import get_data_manager\nfrom models.achg_clip import ACHGCLIP, ACHGCLIPConfig\nfrom models.clip.clip_wrapper import CLIPConfig\nfrom training.trainer import ACHGCLIPTrainer, TrainerConfig\nfrom evaluation.session_evaluator import FSCILSessionEvaluator\nimport transformers\n\nclass LoggerTee:\n    def __init__(self, filename):\n        self.terminal = sys.stdout\n        self.log = open(filename, \"a\", encoding=\"utf-8\")\n\n    def write(self, message):\n        self.terminal.write(message)\n        self.log.write(message)\n        self.log.flush()\n\n    def flush(self):\n        self.terminal.flush()\n        self.log.flush()\n        \n    def isatty(self):\n        return hasattr(self.terminal, 'isatty') and self.terminal.isatty()\n\n# CIFAR100 images are resized to 224x224 in our pipeline.\n# HF CLIP takes 224x224 raw images.\nMAX_TEXT_LEN = 77 # HF max length\nVOCAB_SIZE = 49408 # HF CLIP vocab size\n\nclass SimplePatchifier(nn.Module):\n    def __init__(self, patch_size=32):\n        super().__init__()\n        self.patch_size = patch_size\n        \n    def forward(self, images):\n        # HF CLIP accepts images directly, so we just return them for HF.\n        return images\n\n\ndef main():\n    parser = argparse.ArgumentParser()\n    parser.add_argument(\"--short\", action=\"store_true\", help=\"Run short validation (2 base epochs, 1 inc epoch)\")\n    parser.add_argument(\"--resume_base\", type=str, default=\"\", help=\"Path to a checkpoint to resume base training from\")\n    parser.add_argument(\"--variant\", type=str, default=\"\", help=\"CLIP backbone variant (ViT-B/32, ViT-B/16, ViT-L/14)\")\n    parser.add_argument(\"--seed\", type=int, default=None, help=\"Seed for class split / data manager\")\n    parser.add_argument(\"--data_root\", type=str, default=\"./datasets\", help=\"Path to data root directory\")\n    parser.add_argument(\"--base_epochs\", type=int, default=None, help=\"Base epochs (overrides config)\")\n    parser.add_argument(\"--incremental_epochs\", type=int, default=None, help=\"Incremental epochs (overrides config)\")\n    parser.add_argument(\"--base_batch_size\", type=int, default=None, help=\"Base batch size\")\n    parser.add_argument(\"--incremental_batch_size\", type=int, default=None, help=\"Incremental batch size\")\n    args = parser.parse_args()\n\n    # 1. Generate run folder name\n    run_dir = os.path.join(\"results\", datetime.now().strftime(\"run_%d%m%Y_%H%M%S\"))\n    os.makedirs(run_dir, exist_ok=True)\n    \n    # 2. Redirect stdout/stderr to train_log.txt inside the run folder\n    sys.stdout = LoggerTee(os.path.join(run_dir, \"train_log.txt\"))\n    sys.stderr = sys.stdout\n    \n    print(f\"Starting run. Logs and checkpoints will be saved to {run_dir}\")\n    \n    # 3. Copy configuration files to the run folder for reproducibility\n    config_dest = os.path.join(run_dir, \"configs\")\n    os.makedirs(config_dest, exist_ok=True)\n    for cfg_file in [\"configs/data/cifar100.yaml\", \"configs/training.yaml\", \"configs/model/clip_backbone.yaml\"]:\n        if os.path.exists(cfg_file):\n            shutil.copy(cfg_file, config_dest)\n            print(f\"Copied {cfg_file} to run directory.\")\n            \n    device = torch.device(\"cuda\" if torch.cuda.is_available() else \"cpu\")\n    \n    with open(\"configs/data/cifar100.yaml\", \"r\") as f:\n        data_cfg = yaml.safe_load(f)\n    with open(\"configs/training.yaml\", \"r\") as f:\n        train_cfg = yaml.safe_load(f)\n    with open(\"configs/model/clip_backbone.yaml\", \"r\") as f:\n        model_cfg = yaml.safe_load(f)\n\n    # Apply overrides\n    if args.seed is not None:\n        if isinstance(data_cfg.get(\"seed\"), dict):\n            data_cfg[\"seed\"][\"value\"] = args.seed\n        else:\n            data_cfg[\"seed\"] = args.seed\n    if args.base_batch_size is not None:\n        data_cfg[\"base_batch_size\"][\"value\"] = args.base_batch_size\n    if args.incremental_batch_size is not None:\n        data_cfg[\"incremental_batch_size\"][\"value\"] = args.incremental_batch_size\n    if args.base_epochs is not None:\n        data_cfg[\"base_epochs\"][\"value\"] = args.base_epochs\n    if args.incremental_epochs is not None:\n        data_cfg[\"incremental_epochs\"][\"value\"] = args.incremental_epochs\n\n    variant = args.variant if args.variant else model_cfg.get(\"variant\", {}).get(\"value\", \"ViT-B/32\")\n\n    # Resolve data root path\n    data_root = args.data_root\n    if not os.path.exists(data_root):\n        if os.path.exists(\"D:/FSCIL/datasets\"):\n            data_root = \"D:/FSCIL/datasets\"\n        elif os.path.exists(\"f:/FSCIL/datasets\"):\n            data_root = \"f:/FSCIL/datasets\"\n        else:\n            os.makedirs(data_root, exist_ok=True)\n\n    # Instantiate the data manager\n    print(f\"\\nInitializing Data Manager with data_root={data_root}...\")\n    manager = get_data_manager(data_cfg, data_root=data_root, synthetic=False)\n    \n    print(f\"Dataset availability: Verified.\")\n    print(f\"Base classes (Session 0): {manager.base_classes}\")\n    print(f\"Incremental classes: {manager.incremental_classes}\")\n    print(f\"Total sessions: {manager.num_sessions}\")\n\n    # Initialize CLIPProcessor matching variant\n    hf_model_map = {\n        \"ViT-B/32\": \"openai/clip-vit-base-patch32\",\n        \"ViT-B/16\": \"openai/clip-vit-base-patch16\",\n        \"ViT-L/14\": \"openai/clip-vit-large-patch14\"\n    }\n    hf_model_name = hf_model_map.get(variant, \"openai/clip-vit-base-patch32\")\n    print(f\"\\nLoading HuggingFace CLIPProcessor for {variant} ({hf_model_name})...\")\n    processor = transformers.CLIPProcessor.from_pretrained(hf_model_name)\n\n    # Get class names\n    if hasattr(manager.train_dataset, 'dataset') and hasattr(manager.train_dataset.dataset, 'classes'):\n        class_names = manager.train_dataset.dataset.classes\n    elif hasattr(manager.train_dataset, 'classes'):\n        class_names = manager.train_dataset.classes\n    else:\n        # Fallback if classes attribute missing\n        class_names = [f\"class {i}\" for i in range(100)]\n    \n    # Pre-tokenize all 100 classes\n    text_prompts = [f\"a photo of a {name}\" for name in class_names]\n    text_inputs = processor(text=text_prompts, return_tensors=\"pt\", padding=\"max_length\", max_length=77, truncation=True)\n    global_tokens = text_inputs.input_ids.to(device)\n\n    print(f\"Selected CLIP Variant: {variant}\")\n\n    if variant in [\"ViT-B/32\", \"ViT-B/16\"]:\n        d_model = 768\n        d_e = 512\n        d_k = 64\n        num_heads = 12\n        num_layers = 12\n        ffn_hidden_dim = 3072\n    elif variant == \"ViT-L/14\":\n        d_model = 1024\n        d_e = 768\n        d_k = 64\n        num_heads = 16\n        num_layers = 24\n        ffn_hidden_dim = 4096\n    else:\n        raise ValueError(f\"Unknown variant: {variant}\")\n\n    # Build model Config\n    clip_cfg = CLIPConfig(\n        variant=variant,\n        d_model=d_model,\n        d_e=d_e,\n        d_k=d_k,\n        num_heads=num_heads,\n        num_layers=num_layers,\n        vocab_size=VOCAB_SIZE,\n        max_text_len=MAX_TEXT_LEN,\n        patch_dim=1, # not used by HF, but must be > 0 for validation\n        max_patches=1, # not used by HF, but must be > 0 for validation\n        ffn_hidden_dim=ffn_hidden_dim,\n        dropout=0.0\n    )\n\n    achg_cfg = ACHGCLIPConfig(\n        clip=clip_cfg,\n        num_layers=num_layers,\n        prompt_dim=d_model,\n        node_feature_dim=d_model,\n        mlp_bridge_hidden_dim=256,\n        gin_num_layers=4,\n        gin_hidden_dim=16,\n        acga_latent_dim=64,\n        hgnec_compressed_dim=8,\n        hgnec_restored_dim=16, # restored to gin_hidden_dim\n    )\n\n    print(\"Building model...\")\n    model = ACHGCLIP(achg_cfg)\n    \n    print(\"Setting up TrainerConfig...\")\n    t_cfg = TrainerConfig(\n        lr=train_cfg.get(\"learning_rate\", {}).get(\"value\", 0.000325),\n        weight_decay=train_cfg.get(\"weight_decay\", {}).get(\"value\", 0.001),\n        gradient_accumulation_steps=train_cfg.get(\"gradient_accumulation_steps\", {}).get(\"value\", 3),\n        gradient_clip_max_norm=train_cfg.get(\"gradient_clip_max_norm\", {}).get(\"value\", 4.0),\n    )\n    \n    print(\"Setting up Trainer...\")\n    trainer = ACHGCLIPTrainer(model, t_cfg, device)\n    \n    print(\"Setting up Patchifier...\")\n    patchifier = SimplePatchifier().to(device)\n    \n    # Evaluation Wrapper Setup\n    def get_text_tokens(labels, device):\n        return global_tokens[labels]\n        \n    class WrapperModel(nn.Module):\n        def __init__(self, core_model, patchifier):\n            super().__init__()\n            self.core_model = core_model\n            self.patchifier = patchifier\n            \n        def forward(self, images, labels=None):\n            patches = self.patchifier(images)\n            num_classes = 100\n            tokens = get_text_tokens(torch.arange(num_classes, device=images.device), images.device)\n            out = self.core_model(patches, tokens, dt=0.01)\n            \n            h_v = nn.functional.normalize(out.h_vision, dim=-1)\n            h_t = nn.functional.normalize(out.h_text, dim=-1)\n            \n            logit_scale = 100.0\n            logits = logit_scale * h_v @ h_t.T\n            return logits\n\n    eval_wrapper = WrapperModel(model, patchifier).to(device)\n    evaluator = FSCILSessionEvaluator(\n        model=eval_wrapper,\n        device=device,\n        data_manager=manager,\n    )\n\n    # ---------------------------------------------------------\n    # Base Training (Session 0)\n    # ---------------------------------------------------------\n    base_epochs = 2 if args.short else data_cfg.get(\"base_epochs\", {}).get(\"value\", 3)\n    incremental_epochs = 1 if args.short else data_cfg.get(\"incremental_epochs\", {}).get(\"value\", 5)\n    \n    print(\"\\n==================================================\")\n    print(f\"SESSION 0 (BASE TRAINING) - {base_epochs} epochs\")\n    print(\"==================================================\")\n    session_0 = manager.get_session(0)\n    \n    if args.resume_base:\n        print(f\"Resuming base training from {args.resume_base}\")\n        trainer.load_checkpoint(args.resume_base)\n    \n    best_acc = 0.0\n    start_time = time.time()\n    \n    for epoch in range(base_epochs):\n        print(f\"\\nEpoch {epoch+1}/{base_epochs}\")\n        trainer.train_mode()\n        \n        batch_start_time = time.time()\n        for batch_idx, (images, targets) in enumerate(session_0.train_loader):\n            images = images.to(device)\n            targets = targets.to(device)\n            \n            tokens = global_tokens\n            patches = patchifier(images)\n            loss_dict = trainer.train_step(patches, tokens, targets, dt=0.01)\n            \n            if batch_idx % 20 == 0:\n                elapsed = time.time() - batch_start_time\n                ms_per_batch = (elapsed / 20 * 1000) if batch_idx > 0 else 0\n                print(f\"  Batch {batch_idx}: Total Loss = {loss_dict['L_total']:.4f} | {ms_per_batch:.1f} ms/batch\")\n                batch_start_time = time.time()\n                \n        # Evaluate after epoch\n        print(\"  Evaluating base session accuracy...\")\n        metrics_0 = evaluator.evaluate_session(0)\n        acc = metrics_0['accuracy']\n        print(f\"  Epoch {epoch+1} Accuracy: {acc:.4f}\")\n        \n        # 4. Save Checkpoints\n        trainer.save_checkpoint(os.path.join(run_dir, \"latest_checkpoint.pt\"), seed=42)\n        \n        if acc > best_acc:\n            best_acc = acc\n            trainer.save_checkpoint(os.path.join(run_dir, \"best_checkpoint.pt\"), seed=42)\n            print(f\"  --> New best accuracy! Saved best_checkpoint.pt\")\n            \n        if (epoch + 1) % 5 == 0:\n            trainer.save_checkpoint(os.path.join(run_dir, f\"epoch_{epoch+1}.pt\"), seed=42)\n\n    end_time = time.time()\n    print(f\"\\nSession 0 Training completed in {end_time - start_time:.2f} seconds.\")\n    \n    accuracies = {0: best_acc}\n    \n    # ---------------------------------------------------------\n    # Incremental Sessions (1-8)\n    # ---------------------------------------------------------\n    print(\"\\n--- Starting Incremental Training & Evaluation ---\")\n    \n    for session_idx in range(1, manager.num_sessions):\n        print(f\"\\n==================================================\")\n        print(f\"SESSION {session_idx}\")\n        print(f\"==================================================\")\n        \n        # Load previous session checkpoint or best base checkpoint\n        prev_session_ckpt = os.path.join(run_dir, f\"session_{session_idx-1}.pt\")\n        if session_idx == 1:\n            prev_session_ckpt = os.path.join(run_dir, \"best_checkpoint.pt\")\n            \n        print(f\"Loading checkpoint from: {prev_session_ckpt}\")\n        trainer.load_checkpoint(prev_session_ckpt)\n        \n        session_data = manager.get_session(session_idx)\n        \n        print(\"Training...\")\n        trainer.train_mode()\n        \n        for epoch in range(incremental_epochs):\n            batch_start_time = time.time()\n            for batch_idx, (images, targets) in enumerate(session_data.train_loader):\n                images = images.to(device)\n                targets = targets.to(device)\n                \n                tokens = global_tokens\n                patches = patchifier(images)\n                \n                loss_dict = trainer.train_step(patches, tokens, targets, dt=0.01)\n                \n                if batch_idx % 20 == 0:\n                    elapsed = time.time() - batch_start_time\n                    ms_per_batch = (elapsed / 20 * 1000) if batch_idx > 0 else 0\n                    print(f\"  Batch {batch_idx}: Total Loss = {loss_dict['L_total']:.4f} | {ms_per_batch:.1f} ms/batch\")\n                    batch_start_time = time.time()\n        \n        curr_session_ckpt = os.path.join(run_dir, f\"session_{session_idx}.pt\")\n        trainer.save_checkpoint(curr_session_ckpt, seed=42)\n        print(f\"Saved checkpoint to {curr_session_ckpt}\")\n        \n        print(f\"Evaluating cumulative classes...\")\n        metrics = evaluator.evaluate_session(session_idx)\n        print(f\"Cumulative accuracy: {metrics['accuracy']:.4f}\")\n        accuracies[session_idx] = metrics['accuracy']\n        \n    print(\"\\nValidation Complete.\")\n    \n    # Calculate final metrics requested by the user\n    a_base = accuracies[0]\n    a_last = accuracies[manager.num_sessions - 1]\n    pd = a_base - a_last\n    mean_acc = sum(accuracies.values()) / len(accuracies)\n    \n    total_runtime = time.time() - start_time # Rough approximation for full script runtime\n    \n    final_metrics = {\n        \"Base accuracy (A_base)\": a_base,\n        \"Accuracy after every incremental session\": accuracies,\n        \"A_last\": a_last,\n        \"Mean accuracy\": mean_acc,\n        \"Performance Drop (PD)\": pd,\n        \"Runtime\": total_runtime,\n        \"Exact configuration used\": {\n            \"Data Config\": data_cfg,\n            \"Train Config\": train_cfg,\n        }\n    }\n    \n    print(\"\\n\" + \"=\"*60)\n    print(\"--- FINAL EXPERIMENTAL RESULTS ---\")\n    print(\"=\"*60)\n    print(f\"Backbone Variant : {variant}\")\n    print(f\"Random Seed      : {data_cfg.get('seed', {}).get('value', 42) if isinstance(data_cfg.get('seed'), dict) else data_cfg.get('seed', 42)}\")\n    print(f\"Base Accuracy    : {a_base*100:.2f}%\")\n    print(f\"Final Accuracy   : {a_last*100:.2f}%\")\n    print(f\"Performance Drop : {pd*100:.2f}%\")\n    print(f\"Mean Accuracy    : {mean_acc*100:.2f}%\")\n    print(f\"Total Runtime    : {total_runtime:.1f}s\")\n    print(\"\\nSession Accuracies:\")\n    for s_idx in sorted(accuracies.keys()):\n        print(f\"  Session {s_idx}: {accuracies[s_idx]*100:.2f}%\")\n    print(\"=\"*60 + \"\\n\")\n    \n    # Write to a summary log in results directory\n    with open(os.path.join(run_dir, \"eval_summary.json\"), \"w\") as f:\n        json.dump(final_metrics, f, indent=4)\n\nif __name__ == \"__main__\":\n    main()\n"
with open('run_cifar100.py', 'w', encoding='utf-8') as f:
    f.write(code_cifar)
print('Updated run_cifar100.py')

# Write latest run_experiments.py
code_exp = "import yaml\nimport os\nimport subprocess\nimport shutil\n\ndef modify_yaml(filepath, key, value):\n    with open(filepath, \"r\") as f:\n        cfg = yaml.safe_load(f)\n    if key in cfg:\n        if isinstance(cfg[key], dict) and \"value\" in cfg[key]:\n            cfg[key][\"value\"] = value\n        else:\n            cfg[key] = value\n    else:\n        cfg[key] = {\"value\": value}\n    with open(filepath, \"w\") as f:\n        yaml.dump(cfg, f)\n\ndef run_experiment(name, data_seed, backbone_variant):\n    print(f\"\\n==============================================\")\n    print(f\"Starting Experiment: {name}\")\n    print(f\"==============================================\")\n    \n    # 1. Modify configs\n    modify_yaml(\"configs/data/cifar100.yaml\", \"seed\", data_seed)\n    modify_yaml(\"configs/model/clip_backbone.yaml\", \"variant\", backbone_variant)\n    \n    # 2. Run the training script\n    subprocess.run([\"python\", \"run_cifar100.py\"], check=True)\n    \n    # 3. Find the most recently created run directory in results/\n    results_dir = \"results\"\n    subdirs = [os.path.join(results_dir, d) for d in os.listdir(results_dir) if os.path.isdir(os.path.join(results_dir, d)) and d.startswith(\"run_\")]\n    if subdirs:\n        latest_run = max(subdirs, key=os.path.getmtime)\n        \n        # 4. Rename it to the experiment name for easy tracking\n        new_dir = os.path.join(results_dir, name)\n        if os.path.exists(new_dir):\n            shutil.rmtree(new_dir)\n        os.rename(latest_run, new_dir)\n        print(f\"Experiment {name} saved to {new_dir}\\n\")\n\nif __name__ == \"__main__\":\n    import argparse\n    parser = argparse.ArgumentParser()\n    parser.add_argument(\"--experiment\", type=str, default=\"all\", choices=[\"all\", \"SplitStudy\", \"Backbone_CLIP_B\", \"Backbone_CLIP_C\"], help=\"Experiment to run\")\n    args = parser.parse_args()\n\n    # Baseline configs to restore later\n    original_seed = 42\n    original_variant = \"ViT-B/32\"\n    \n    try:\n        if args.experiment in [\"all\", \"SplitStudy\"]:\n            # Experiment A: Split B (Seed 1993, ViT-B/32)\n            run_experiment(\"SplitStudy\", 1993, \"ViT-B/32\")\n            \n        if args.experiment in [\"all\", \"Backbone_CLIP_B\"]:\n            # Experiment B1: Backbone CLIP-B (Seed 42, ViT-B/16)\n            run_experiment(\"Backbone_CLIP_B\", 42, \"ViT-B/16\")\n            \n        if args.experiment in [\"all\", \"Backbone_CLIP_C\"]:\n            # Experiment B2: Backbone CLIP-C (Seed 42, ViT-L/14)\n            run_experiment(\"Backbone_CLIP_C\", 42, \"ViT-L/14\")\n            \n    finally:\n        # Always restore baseline configs\n        modify_yaml(\"configs/data/cifar100.yaml\", \"seed\", original_seed)\n        modify_yaml(\"configs/model/clip_backbone.yaml\", \"variant\", original_variant)\n        print(\"Restored baseline configs.\")\n"
with open('run_experiments.py', 'w', encoding='utf-8') as f:
    f.write(code_exp)
print('Updated run_experiments.py')
# Out:
# Updated run_cifar100.py
# Updated run_experiments.py

# %%
import subprocess
import sys

print('Starting Experiment B2 (ViT-L/14, Seed 42)...')
cmd = [sys.executable, 'run_cifar100.py', '--variant', 'ViT-L/14', '--seed', '42', '--data_root', './datasets']

process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1)
for line in process.stdout:
    print(line, end='', flush=True)
process.wait()

if process.returncode != 0:
    raise RuntimeError(f'Training failed with exit code {process.returncode}')
# Out:
# Starting Experiment B2 (ViT-L/14, Seed 42)...
# Starting run. Logs and checkpoints will be saved to results/run_01092026_050426
# Copied configs/data/cifar100.yaml to run directory.
# Copied configs/training.yaml to run directory.
# Copied configs/model/clip_backbone.yaml to run directory.
#
# Initializing Data Manager with data_root=./datasets...
# Downloading https://cave.cs.toronto.edu/kriz/cifar-100-python.tar.gz to ./datasets/cifar-100-python.tar.gz
#
#   0%|          | 0/169001437 [00:00<?, ?it/s]
#   0%|          | 32768/169001437 [00:00<39:03, 72089.78it/s]
#   0%|          | 65536/169001437 [00:00<39:07, 71959.30it/s]
#   0%|          | 98304/169001437 [00:01<39:12, 71795.00it/s]
#   0%|          | 131072/169001437 [00:01<39:10, 71845.78it/s]
#   0%|          | 163840/169001437 [00:02<39:15, 71684.89it/s]
#   0%|          | 196608/169001437 [00:02<39:14, 71681.75it/s]
#   0%|          | 229376/169001437 [00:03<46:16, 60776.89it/s]
#   0%|          | 262144/169001437 [00:04<1:08:01, 41338.59it/s]
#   0%|          | 294912/169001437 [00:05<1:12:34, 38739.41it/s]
#   0%|          | 327680/169001437 [00:06<1:10:17, 39995.04it/s]
#   0%|          | 360448/169001437 [00:07<1:03:57, 43941.23it/s]
#   0%|          | 393216/169001437 [00:07<1:04:26, 43609.11it/s]
#   0%|          | 425984/169001437 [00:08<54:55, 51152.90it/s]
#   0%|          | 458752/169001437 [00:08<53:17, 52715.30it/s]
#   0%|          | 491520/169001437 [00:09<57:21, 48969.61it/s]
#   0%|          | 524288/169001437 [00:10<59:59, 46809.75it/s]
#  14%|#4        | 24117248/169001437 [05:58<34:44, 69514.42it/s]
#  14%|#4        | 24150016/169001437 [05:59<34:41, 69580.61it/s]
#  14%|#4        | 24182784/169001437 [05:59<34:41, 69559.47it/s]
#  14%|#4        | 24215552/169001437 [06:00<34:36, 69730.50it/s]
#  14%|#4        | 24248320/169001437 [06:00<36:56, 65319.03it/s]
#  14%|#4        | 24281088/169001437 [06:01<36:06, 66797.42it/s]
#  14%|#4        | 24313856/169001437 [06:01<35:35, 67762.99it/s]
#  14%|#4        | 24346624/169001437 [06:02<35:12, 68477.26it/s]
#  14%|#4        | 24379392/169001437 [06:02<35:09, 68561.16it/s]
#  14%|#4        | 24412160/169001437 [06:03<35:04, 68689.61it/s]
#  14%|#4        | 24444928/169001437 [06:03<34:56, 68948.17it/s]
# ...
#   Batch 3300: Total Loss = -0.0173 | 743.1 ms/batch
#   Batch 3320: Total Loss = 0.7861 | 743.3 ms/batch
#   Batch 3340: Total Loss = 0.2885 | 742.2 ms/batch
#   Batch 3360: Total Loss = 0.6615 | 743.9 ms/batch
#   Batch 3380: Total Loss = -0.0290 | 744.2 ms/batch
#   Batch 3400: Total Loss = -0.0264 | 743.7 ms/batch
#   Batch 3420: Total Loss = -0.0165 | 744.3 ms/batch
#   Batch 3440: Total Loss = -0.0174 | 743.0 ms/batch
#   Batch 3460: Total Loss = 0.0863 | 744.3 ms/batch
#   Batch 3480: Total Loss = 0.7410 | 744.4 ms/batch
#   Batch 3500: Total Loss = -0.0184 | 744.5 ms/batch
#   Batch 3520: Total Loss = 0.2629 | 744.7 ms/batch
#   Batch 3540: Total Loss = -0.0003 | 743.9 ms/batch
#   Batch 3560: Total Loss = -0.0054 | 745.0 ms/batch
#   Batch 3580: Total Loss = 0.4196 | 744.7 ms/batch
#   Batch 3600: Total Loss = 0.0577 | 744.1 ms/batch
#   Batch 3620: Total Loss = 0.2850 | 744.9 ms/batch
#   Batch 3640: Total Loss = 0.5853 | 745.8 ms/batch
#   Batch 3660: Total Loss = -0.0276 | 744.2 ms/batch
#   Batch 3680: Total Loss = 1.5757 | 743.2 ms/batch
#   Batch 3700: Total Loss = -0.0200 | 744.2 ms/batch
#   Batch 3720: Total Loss = -0.0250 | 744.5 ms/batch
#   Batch 3740: Total Loss = -0.0154 | 743.7 ms/batch
#   Batch 3760: Total Loss = -0.0181 | 743.7 ms/batch
#   Batch 3780: Total Loss = -0.0253 | 744.4 ms/batch
#   Batch 3800: Total Loss = -0.0001 | 743.9 ms/batch
#   Batch 3820: Total Loss = 2.7185 | 742.8 ms/batch
#   Batch 3840: Total Loss = -0.0227 | 743.1 ms/batch
#   Batch 3860: Total Loss = 0.0085 | 744.1 ms/batch
#   Batch 3880: Total Loss = 0.5134 | 743.3 ms/batch
#   Batch 3900: Total Loss = -0.0046 | 743.7 ms/batch
#   Batch 3920: Total Loss = -0.0183 | 743.9 ms/batch
#   Batch 3940: Total Loss = -0.0275 | 743.9 ms/batch
#   Batch 3960: Total Loss = -0.0127 | 743.4 ms/batch
#   Batch 3980: Total Loss = 0.0104 | 743.3 ms/batch
#   Batch 4000: Total Loss = -0.0106 | 743.8 ms/batch
#   Batch 4020: Total Loss = -0.0268 | 744.5 ms/batch
#   Batch 4040: Total Loss = 0.1240 | 744.0 ms/batch
#   Batch 4060: Total Loss = -0.0281 | 743.9 ms/batch
#   Batch 4080: Total Loss = 0.2740 | 743.4 ms/batch
#   Batch 4100: Total Loss = 0.0291 | 743.2 ms/batch
#   Batch 4120: Total Loss = -0.0241 | 743.9 ms/batch
#   Batch 4140: Total Loss = 0.1031 | 743.5 ms/batch
#   Batch 4160: Total Loss = 0.0337 | 742.5 ms/batch
#   Batch 4180: Total Loss = 0.0055 | 742.7 ms/batch
#   Batch 4200: Total Loss = 0.0031 | 744.1 ms/batch
#   Batch 4220: Total Loss = -0.0287 | 744.9 ms/batch
#   Batch 4240: Total Loss = 0.7643 | 744.5 ms/batch
#   Batch 4260: Total Loss = 0.9858 | 744.8 ms/batch
#   Batch 4280: Total Loss = 0.7020 | 744.8 ms/batch
#   Batch 4300: Total Loss = -0.0215 | 744.8 ms/batch
#   Batch 4320: Total Loss = 0.9847 | 743.5 ms/batch
#   Batch 4340: Total Loss = 0.0093 | 744.5 ms/batch
#   Batch 4360: Total Loss = 0.1684 | 744.2 ms/batch
#   Batch 4380: Total Loss = -0.0240 | 743.7 ms/batch
#   Batch 4400: Total Loss = 0.0354 | 744.3 ms/batch
#   Batch 4420: Total Loss = 0.0652 | 743.9 ms/batch
#   Batch 4440: Total Loss = 0.0090 | 743.4 ms/batch
#   Batch 4460: Total Loss = 0.2411 | 744.3 ms/batch
#   Batch 4480: Total Loss = 0.0525 | 743.1 ms/batch
#   Batch 4500: Total Loss = 0.6968 | 743.7 ms/batch
#   Batch 4520: Total Loss = 0.4726 | 745.8 ms/batch
#   Batch 4540: Total Loss = -0.0259 | 744.7 ms/batch
#   Batch 4560: Total Loss = 0.4598 | 743.9 ms/batch
#   Batch 4580: Total Loss = 0.3751 | 744.8 ms/batch
#   Batch 4600: Total Loss = 0.0373 | 743.6 ms/batch
#   Batch 4620: Total Loss = 0.0822 | 744.4 ms/batch
#   Batch 4640: Total Loss = 0.0086 | 743.9 ms/batch
#   Batch 4660: Total Loss = 1.8041 | 744.5 ms/batch
#   Batch 4680: Total Loss = 0.2146 | 743.0 ms/batch
#   Batch 4700: Total Loss = -0.0254 | 743.7 ms/batch
#   Batch 4720: Total Loss = 0.1713 | 742.6 ms/batch
#   Batch 4740: Total Loss = 0.0506 | 742.2 ms/batch
#   Batch 4760: Total Loss = -0.0066 | 744.5 ms/batch
#   Batch 4780: Total Loss = -0.0284 | 744.1 ms/batch
#   Batch 4800: Total Loss = 0.0078 | 744.1 ms/batch
#   Batch 4820: Total Loss = -0.0173 | 744.9 ms/batch
#   Batch 4840: Total Loss = 1.4939 | 744.5 ms/batch
#   Batch 4860: Total Loss = 0.1981 | 743.5 ms/batch
#   Batch 4880: Total Loss = 0.7212 | 744.6 ms/batch
#   Batch 4900: Total Loss = 0.4250 | 743.7 ms/batch
#   Batch 4920: Total Loss = 0.2381 | 744.3 ms/batch
#   Batch 4940: Total Loss = 0.3827 | 744.5 ms/batch
#   Batch 4960: Total Loss = -0.0245 | 744.1 ms/batch
#   Batch 4980: Total Loss = 0.0602 | 743.9 ms/batch
#   Batch 5000: Total Loss = 0.1070 | 745.0 ms/batch
#   Batch 5020: Total Loss = -0.0118 | 744.4 ms/batch
#   Batch 5040: Total Loss = 1.2179 | 744.9 ms/batch
#   Batch 5060: Total Loss = 0.2802 | 744.9 ms/batch
#   Batch 5080: Total Loss = 0.0335 | 745.0 ms/batch
#   Batch 5100: Total Loss = 0.0537 | 743.2 ms/batch
#   Batch 5120: Total Loss = -0.0268 | 743.3 ms/batch
#   Batch 5140: Total Loss = -0.0126 | 745.0 ms/batch
#   Batch 5160: Total Loss = -0.0233 | 743.9 ms/batch
#   Batch 5180: Total Loss = -0.0292 | 743.8 ms/batch
#   Batch 5200: Total Loss = -0.0274 | 743.9 ms/batch
#   Batch 5220: Total Loss = 0.5128 | 743.2 ms/batch
#   Batch 5240: Total Loss = -0.0235 | 744.0 ms/batch
#   Batch 5260: Total Loss = 0.1147 | 744.1 ms/batch
#   Batch 5280: Total Loss = 0.2454 | 745.5 ms/batch
#   Batch 5300: Total Loss = -0.0107 | 744.4 ms/batch
#   Batch 5320: Total Loss = 0.0099 | 743.6 ms/batch
#   Batch 5340: Total Loss = 0.1546 | 743.6 ms/batch
#   Batch 5360: Total Loss = 0.0284 | 744.0 ms/batch
#   Batch 5380: Total Loss = 2.1067 | 744.0 ms/batch
#   Batch 5400: Total Loss = -0.0216 | 742.9 ms/batch
#   Batch 5420: Total Loss = -0.0230 | 743.4 ms/batch
#   Batch 5440: Total Loss = 0.1008 | 743.3 ms/batch
#   Batch 5460: Total Loss = -0.0287 | 744.1 ms/batch
#   Batch 5480: Total Loss = 0.3884 | 744.3 ms/batch
#   Batch 5500: Total Loss = 0.2289 | 745.0 ms/batch
#   Batch 5520: Total Loss = -0.0272 | 744.1 ms/batch
#   Batch 5540: Total Loss = 0.0278 | 743.0 ms/batch
#   Batch 5560: Total Loss = 0.0014 | 743.9 ms/batch
#   Batch 5580: Total Loss = 1.1493 | 743.9 ms/batch
#   Batch 5600: Total Loss = -0.0173 | 744.0 ms/batch
#   Batch 5620: Total Loss = 0.0811 | 743.6 ms/batch
#   Batch 5640: Total Loss = 0.0019 | 744.9 ms/batch
#   Batch 5660: Total Loss = 0.2188 | 744.7 ms/batch
#   Batch 5680: Total Loss = 0.0065 | 743.9 ms/batch
#   Batch 5700: Total Loss = -0.0267 | 743.6 ms/batch
#   Batch 5720: Total Loss = -0.0213 | 744.3 ms/batch
#   Batch 5740: Total Loss = 0.0005 | 743.4 ms/batch
#   Batch 5760: Total Loss = 1.0343 | 744.1 ms/batch
#   Batch 5780: Total Loss = 1.1564 | 743.6 ms/batch
#   Batch 5800: Total Loss = 0.0169 | 744.5 ms/batch
#   Batch 5820: Total Loss = 0.2584 | 744.7 ms/batch
#   Batch 5840: Total Loss = 0.1118 | 743.7 ms/batch
#   Batch 5860: Total Loss = -0.0296 | 744.5 ms/batch
#   Batch 5880: Total Loss = 0.8076 | 744.4 ms/batch
#   Batch 5900: Total Loss = 0.3535 | 744.7 ms/batch
#   Batch 5920: Total Loss = 0.2615 | 743.5 ms/batch
#   Batch 5940: Total Loss = 0.8968 | 743.2 ms/batch
#   Batch 5960: Total Loss = 0.0756 | 743.5 ms/batch
#   Batch 5980: Total Loss = -0.0207 | 744.4 ms/batch
#   Batch 6000: Total Loss = 0.0093 | 744.0 ms/batch
#   Batch 6020: Total Loss = 0.3597 | 743.2 ms/batch
#   Batch 6040: Total Loss = 0.4943 | 743.8 ms/batch
#   Batch 6060: Total Loss = 0.0651 | 742.9 ms/batch
#   Batch 6080: Total Loss = 0.4323 | 743.6 ms/batch
#   Batch 6100: Total Loss = 0.0626 | 743.4 ms/batch
#   Batch 6120: Total Loss = 0.0436 | 744.0 ms/batch
#   Batch 6140: Total Loss = 0.2134 | 744.7 ms/batch
#   Batch 6160: Total Loss = -0.0082 | 744.2 ms/batch
#   Batch 6180: Total Loss = 0.5105 | 743.6 ms/batch
#   Batch 6200: Total Loss = -0.0222 | 743.3 ms/batch
#   Batch 6220: Total Loss = 0.1882 | 743.1 ms/batch
#   Batch 6240: Total Loss = -0.0255 | 743.5 ms/batch
#   Batch 6260: Total Loss = 0.0189 | 744.9 ms/batch
#   Batch 6280: Total Loss = -0.0247 | 744.3 ms/batch
#   Batch 6300: Total Loss = 0.2079 | 744.2 ms/batch
#   Batch 6320: Total Loss = -0.0265 | 742.5 ms/batch
#   Batch 6340: Total Loss = 0.0793 | 744.0 ms/batch
#   Batch 6360: Total Loss = 0.3178 | 744.1 ms/batch
#   Batch 6380: Total Loss = 0.2180 | 745.9 ms/batch
#   Batch 6400: Total Loss = -0.0279 | 745.4 ms/batch
#   Batch 6420: Total Loss = 0.1910 | 744.8 ms/batch
#   Batch 6440: Total Loss = 0.5162 | 743.5 ms/batch
#   Batch 6460: Total Loss = 0.1263 | 743.7 ms/batch
#   Batch 6480: Total Loss = -0.0202 | 744.0 ms/batch
#   Batch 6500: Total Loss = -0.0242 | 745.5 ms/batch
#   Batch 6520: Total Loss = -0.0231 | 744.1 ms/batch
#   Batch 6540: Total Loss = 0.0588 | 744.2 ms/batch
#   Batch 6560: Total Loss = 0.0392 | 744.0 ms/batch
#   Batch 6580: Total Loss = -0.0257 | 742.8 ms/batch
#   Batch 6600: Total Loss = 2.4191 | 742.8 ms/batch
#   Batch 6620: Total Loss = 0.1666 | 743.7 ms/batch
#   Batch 6640: Total Loss = -0.0177 | 742.9 ms/batch
#   Batch 6660: Total Loss = 0.6581 | 743.1 ms/batch
#   Batch 6680: Total Loss = 0.0495 | 742.5 ms/batch
#   Batch 6700: Total Loss = -0.0214 | 743.4 ms/batch
#   Batch 6720: Total Loss = 0.3406 | 744.5 ms/batch
#   Batch 6740: Total Loss = 0.9610 | 743.7 ms/batch
#   Batch 6760: Total Loss = -0.0271 | 744.1 ms/batch
#   Batch 6780: Total Loss = 0.0286 | 745.2 ms/batch
#   Batch 6800: Total Loss = 0.4914 | 743.5 ms/batch
#   Batch 6820: Total Loss = 0.0134 | 744.1 ms/batch
#   Batch 6840: Total Loss = -0.0227 | 745.1 ms/batch
#   Batch 6860: Total Loss = 0.7326 | 745.9 ms/batch
#   Batch 6880: Total Loss = -0.0284 | 744.5 ms/batch
#   Batch 6900: Total Loss = -0.0268 | 743.6 ms/batch
#   Batch 6920: Total Loss = 0.0417 | 743.0 ms/batch
#   Batch 6940: Total Loss = 0.0212 | 742.0 ms/batch
#   Batch 6960: Total Loss = 0.0070 | 742.3 ms/batch
#   Batch 6980: Total Loss = -0.0009 | 744.9 ms/batch
#   Batch 7000: Total Loss = -0.0124 | 743.6 ms/batch
#   Batch 7020: Total Loss = -0.0210 | 744.4 ms/batch
#   Batch 7040: Total Loss = 0.7151 | 744.3 ms/batch
#   Batch 7060: Total Loss = 0.4761 | 743.9 ms/batch
#   Batch 7080: Total Loss = -0.0232 | 743.4 ms/batch
#   Batch 7100: Total Loss = 0.4082 | 742.4 ms/batch
#   Batch 7120: Total Loss = 0.0932 | 743.8 ms/batch
#   Batch 7140: Total Loss = 0.2502 | 743.2 ms/batch
#   Batch 7160: Total Loss = -0.0260 | 744.4 ms/batch
#   Batch 7180: Total Loss = -0.0181 | 743.5 ms/batch
#   Batch 7200: Total Loss = 1.1001 | 744.1 ms/batch
#   Batch 7220: Total Loss = 0.0083 | 742.8 ms/batch
#   Batch 7240: Total Loss = 0.0758 | 744.1 ms/batch
#   Batch 7260: Total Loss = 0.0782 | 744.3 ms/batch
#   Batch 7280: Total Loss = 0.3918 | 744.1 ms/batch
#   Batch 7300: Total Loss = 0.7350 | 744.5 ms/batch
#   Batch 7320: Total Loss = 0.7370 | 743.2 ms/batch
#   Batch 7340: Total Loss = -0.0211 | 745.2 ms/batch
#   Batch 7360: Total Loss = 0.2406 | 745.2 ms/batch
#   Batch 7380: Total Loss = -0.0269 | 745.2 ms/batch
#   Batch 7400: Total Loss = 0.1021 | 745.7 ms/batch
#   Batch 7420: Total Loss = -0.0098 | 745.4 ms/batch
#   Batch 7440: Total Loss = 0.1456 | 744.7 ms/batch
#   Batch 7460: Total Loss = 0.0664 | 744.9 ms/batch
#   Batch 7480: Total Loss = 0.2632 | 744.0 ms/batch
#   Evaluating base session accuracy...
#   Epoch 3 Accuracy: 0.9103
#   --> New best accuracy! Saved best_checkpoint.pt
#
# Session 0 Training completed in 18257.47 seconds.
#
# --- Starting Incremental Training & Evaluation ---
#
# ==================================================
# SESSION 1
# ==================================================
# Loading checkpoint from: results/run_01092026_050426/best_checkpoint.pt
# Training...
#   Batch 0: Total Loss = 3.6145 | 0.0 ms/batch
#   Batch 0: Total Loss = 4.9614 | 0.0 ms/batch
#   Batch 0: Total Loss = 5.2617 | 0.0 ms/batch
#   Batch 0: Total Loss = 2.4192 | 0.0 ms/batch
#   Batch 0: Total Loss = 3.4454 | 0.0 ms/batch
# Saved checkpoint to results/run_01092026_050426/session_1.pt
# Evaluating cumulative classes...
# Cumulative accuracy: 0.8792
#
# ==================================================
# SESSION 2
# ==================================================
# Loading checkpoint from: results/run_01092026_050426/session_1.pt
# Training...
#   Batch 0: Total Loss = 3.6539 | 0.0 ms/batch
#   Batch 0: Total Loss = 6.3339 | 0.0 ms/batch
#   Batch 0: Total Loss = 2.7981 | 0.0 ms/batch
#   Batch 0: Total Loss = 4.8562 | 0.0 ms/batch
#   Batch 0: Total Loss = 2.7098 | 0.0 ms/batch
# Saved checkpoint to results/run_01092026_050426/session_2.pt
# Evaluating cumulative classes...
# Cumulative accuracy: 0.8567
#
# ==================================================
# SESSION 3
# ==================================================
# Loading checkpoint from: results/run_01092026_050426/session_2.pt
# Training...
#   Batch 0: Total Loss = 0.2820 | 0.0 ms/batch
#   Batch 0: Total Loss = 3.7682 | 0.0 ms/batch
#   Batch 0: Total Loss = 0.5355 | 0.0 ms/batch
#   Batch 0: Total Loss = 0.0833 | 0.0 ms/batch
#   Batch 0: Total Loss = 1.1934 | 0.0 ms/batch
# Saved checkpoint to results/run_01092026_050426/session_3.pt
# Evaluating cumulative classes...
# Cumulative accuracy: 0.8596
#
# ==================================================
# SESSION 4
# ==================================================
# Loading checkpoint from: results/run_01092026_050426/session_3.pt
# Training...
#   Batch 0: Total Loss = 2.2163 | 0.0 ms/batch
#   Batch 0: Total Loss = 1.2794 | 0.0 ms/batch
#   Batch 0: Total Loss = 2.5960 | 0.0 ms/batch
#   Batch 0: Total Loss = 0.6711 | 0.0 ms/batch
#   Batch 0: Total Loss = 1.7935 | 0.0 ms/batch
# Saved checkpoint to results/run_01092026_050426/session_4.pt
# Evaluating cumulative classes...
# Cumulative accuracy: 0.8542
#
# ==================================================
# SESSION 5
# ==================================================
# Loading checkpoint from: results/run_01092026_050426/session_4.pt
# Training...
#   Batch 0: Total Loss = 1.8947 | 0.0 ms/batch
#   Batch 0: Total Loss = 1.8181 | 0.0 ms/batch
#   Batch 0: Total Loss = 1.5038 | 0.0 ms/batch
#   Batch 0: Total Loss = 0.2572 | 0.0 ms/batch
#   Batch 0: Total Loss = 1.1621 | 0.0 ms/batch
# Saved checkpoint to results/run_01092026_050426/session_5.pt
# Evaluating cumulative classes...
# Cumulative accuracy: 0.8501
#
# ==================================================
# SESSION 6
# ==================================================
# Loading checkpoint from: results/run_01092026_050426/session_5.pt
# Training...
#   Batch 0: Total Loss = 3.0661 | 0.0 ms/batch
#   Batch 0: Total Loss = 1.7702 | 0.0 ms/batch
#   Batch 0: Total Loss = 0.8625 | 0.0 ms/batch
#   Batch 0: Total Loss = 2.2402 | 0.0 ms/batch
#   Batch 0: Total Loss = 1.5112 | 0.0 ms/batch
# Saved checkpoint to results/run_01092026_050426/session_6.pt
# Evaluating cumulative classes...
# Cumulative accuracy: 0.8453
#
# ==================================================
# SESSION 7
# ==================================================
# Loading checkpoint from: results/run_01092026_050426/session_6.pt
# Training...
#   Batch 0: Total Loss = 2.5808 | 0.0 ms/batch
#   Batch 0: Total Loss = 1.5031 | 0.0 ms/batch
#   Batch 0: Total Loss = 2.0154 | 0.0 ms/batch
#   Batch 0: Total Loss = 2.2685 | 0.0 ms/batch
#   Batch 0: Total Loss = 1.4844 | 0.0 ms/batch
# Saved checkpoint to results/run_01092026_050426/session_7.pt
# Evaluating cumulative classes...
# Cumulative accuracy: 0.8339
#
# ==================================================
# SESSION 8
# ==================================================
# Loading checkpoint from: results/run_01092026_050426/session_7.pt
# Training...
#   Batch 0: Total Loss = 0.4919 | 0.0 ms/batch
#   Batch 0: Total Loss = 0.5780 | 0.0 ms/batch
#   Batch 0: Total Loss = 0.0814 | 0.0 ms/batch
#   Batch 0: Total Loss = 0.4420 | 0.0 ms/batch
#   Batch 0: Total Loss = 1.3764 | 0.0 ms/batch
# Saved checkpoint to results/run_01092026_050426/session_8.pt
# Evaluating cumulative classes...
# Cumulative accuracy: 0.8301
#
# Validation Complete.
#
# ============================================================
# --- FINAL EXPERIMENTAL RESULTS ---
# ============================================================
# Backbone Variant : ViT-L/14
# Random Seed      : 42
# Base Accuracy    : 91.03%
# Final Accuracy   : 83.01%
# Performance Drop : 8.02%
# Mean Accuracy    : 85.77%
# Total Runtime    : 24021.3s
#
# Session Accuracies:
#   Session 0: 91.03%
#   Session 1: 87.92%
#   Session 2: 85.67%
#   Session 3: 85.96%
#   Session 4: 85.42%
#   Session 5: 85.01%
#   Session 6: 84.53%
#   Session 7: 83.39%
#   Session 8: 83.01%
# ============================================================

# %%
import os
import json
import shutil

results_dir = 'results'
subdirs = [os.path.join(results_dir, d) for d in os.listdir(results_dir) if os.path.isdir(os.path.join(results_dir, d)) and d.startswith('run_')]
if subdirs:
    latest_run = max(subdirs, key=os.path.getmtime)
    print(f'Latest run folder: {latest_run}')
    summary_file = os.path.join(latest_run, 'eval_summary.json')
    if os.path.exists(summary_file):
        with open(summary_file, 'r') as f:
            summary = json.load(f)
        print('\n' + '='*60)
        print('FINAL EVALUATION SUMMARY')
        print('='*60)
        print(json.dumps(summary, indent=2))
        shutil.copy(summary_file, '/kaggle/working/eval_summary.json')
    
    # Copy results artifacts to /kaggle/working
    dest = '/kaggle/working/Backbone_CLIP_C_ViTL14'
    if os.path.exists(dest):
        shutil.rmtree(dest)
    shutil.copytree(latest_run, dest)
    print(f'\nArtifacts saved to {dest}')
# Out:
# Latest run folder: results/run_01092026_050426
#
# ============================================================
# FINAL EVALUATION SUMMARY
# ============================================================
# {
#   "Base accuracy (A_base)": 0.9103333333333333,
#   "Accuracy after every incremental session": {
#     "0": 0.9103333333333333,
#     "1": 0.8792307692307693,
#     "2": 0.8567142857142858,
#     "3": 0.8596,
#     "4": 0.85425,
#     "5": 0.8501176470588235,
#     "6": 0.8453333333333334,
#     "7": 0.8338947368421052,
#     "8": 0.8301
#   },
#   "A_last": 0.8301,
#   "Mean accuracy": 0.8577304561680723,
#   "Performance Drop (PD)": 0.08023333333333338,
#   "Runtime": 24021.253116607666,
#   "Exact configuration used": {
#     "Data Config": {
#       "base_batch_size": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.B: 'For the training of base classes, we set the batch size to 4'.",
#         "value": 4
#       },
#       "base_classes": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.A: 'We designated 60 classes as base classes'.",
#         "value": 60
#       },
#       "base_epochs": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.B: 'and the number of training epochs to 3.'",
#         "value": 3
#       },
#       "class_split_source": {
#         "provenance": "IMPLEMENTATION_CHOICE",
#         "source": "Functional Baseline: No explicit standard split was found, CEC splits are commonly used, but without author confirmation we generate a pseudo-random permutation from seed.",
#         "value": "deterministic_pseudo_random"
#       },
#       "classes_per_incremental_session": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.A: 'each introducing 5 new classes with 5 samples per class' (5-way).",
#         "value": 5
#       },
#       "dataset_name": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.A / V.A bullet 1.",
#         "value": "CIFAR-100"
#       },
#       "image_channels": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.A: 'RGB'.",
#         "value": 3
#       },
#       "image_size": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.A (same sentence).",
#         "value": 32
#       },
#       "incremental_batch_size": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.B: 'In the incremental learning phase, the batch size and the number of training epochs were set to 4 and 5, respectively.'",
#         "value": 4
#       },
#       "incremental_classes_total": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.A: 'and the remaining 40 as incremental classes.'",
#         "value": 40
#       },
#       "incremental_epochs": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.B (same sentence).",
#         "value": 5
#       },
#       "num_incremental_sessions": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.A: 'These incremental classes are divided into 8 sessions'.",
#         "value": 8
#       },
#       "preprocessing_normalization": {
#         "provenance": "IMPLEMENTATION_CHOICE",
#         "source": "Standard CLIP expectation (model is frozen so it requires proper normalization and seq length).",
#         "value": "mean=[0.481, 0.457, 0.408], std=[0.268, 0.261, 0.275], resize=224"
#       },
#       "seed": {
#         "value": 42
#       },
#       "shots_per_class": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.A (same sentence, 5-shot).",
#         "value": 5
#       },
#       "test_set_composition": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.A/Tables I: per-session accuracy columns evaluate over all classes seen so far (cumulative class-incremental evaluation), per Section III.A's problem formalization.",
#         "value": "cumulative_all_classes_seen_so_far"
#       },
#       "total_classes": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.A.",
#         "value": 100
#       },
#       "total_images": {
#         "provenance": "PAPER_FACT",
#         "source": "Section V.A: 'This dataset consists of 60,000 32x32 RGB images across 100 classes.'",
#         "value": 60000
#       }
#     },
#     "Train Config": {
#       "optimizer": {
#         "value": "Lion",
#         "provenance": "PAPER_FACT",
#         "source": "Section V.B: 'For optimization, we employed the Lion optimizer [59]...'"
#       },
#       "learning_rate": {
#         "value": 0.000325,
#         "provenance": "PAPER_FACT",
#         "source": "Section V.B: 'with a learning rate of 0.000325'."
#       },
#       "weight_decay": {
#         "value": 0.001,
#         "provenance": "PAPER_FACT",
#         "source": "Section V.B: 'and a weight decay of 1e-3'."
#       },
#       "scheduler": {
#         "value": "CosineAnnealingWarmupRestarts",
#         "provenance": "PAPER_FACT",
#         "source": "Section V.B: 'combined with the CosineAnnealingWarmupRestarts scheduler [60] for dynamic learning rate adjustment.'"
#       },
#       "scheduler_warmup_steps": {
#         "value": null,
#         "provenance": "UNRESOLVED",
#         "source": "Section V.B names the scheduler but gives no warmup length anywhere."
#       },
#       "scheduler_restart_period": {
#         "value": null,
#         "provenance": "UNRESOLVED",
#         "source": "Section V.B names the scheduler but gives no restart period anywhere."
#       },
#       "gradient_accumulation_steps": {
#         "value": 3,
#         "provenance": "PAPER_FACT",
#         "source": "Section V.B: 'we adopted gradient accumulation over 3 steps'."
#       },
#       "gradient_clip_max_norm": {
#         "value": 4.0,
#         "provenance": "PAPER_FACT",
#         "source": "Section V.B: 'and gradient clipping with a maximum norm of 4.0.'"
#       },
#       "lambda_recon": {
#         "value": 0.04,
#         "provenance": "PAPER_FACT",
#         "source": "Section V.B: 'The coefficients assigned to the ACGA loss and the HGN-EC loss within the total loss function were set to 0.04.'"
#       },
#       "lambda_adv": {
#         "value": 0.04,
#         "provenance": "PAPER_FACT",
#         "source": "Section V.B: 'The coefficients assigned to the ACGA loss and the HGN-EC loss within the total loss function were set to 0.04.'"
#       },
#       "lambda_energy": {
#         "value": 0.04,
#         "provenance": "PAPER_FACT",
#         "source": "Section V.B: 'The coefficients assigned to the ACGA loss and the HGN-EC loss within the total loss function were set to 0.04.'"
#       }
#     }
#   }
# }
#
# Artifacts saved to /kaggle/working/Backbone_CLIP_C_ViTL14
